# %% [markdown]
# # Project: Predicting users’ personality trait based groups and users’ recommendation

# %% [markdown]
# Github Link : https://github.com/S-Delowar/Data-Science-Machine-Learning/blob/main/DA_Project_Group_6.ipynb

# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', None)
import warnings
warnings.filterwarnings('ignore')

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %% [markdown]
# # Descriptive Analysis with IPIP Scores (like sheet)

# %%
df = pd.read_csv('IPIP Scores_likes.csv')

# %%
df.head()
# Out:
#                                   Filename    WC    WPS  Qmarks  Unique  \
# 0  A M Tauhidul Karim Drubo_AIUB_likes.txt  1424  16.56     0.0   49.37
# 1        aarif hossain-693654204025796.txt  1461  20.29     0.0   51.33
# 2     Abdul Motalib Shaykat_AIUB_likes.txt  1319  17.59     0.0   47.99
# 3            Abhijit Mondal_AIUB_likes.txt  1475  16.39     0.0   48.34
# 4             abhishek Saha_AIUB_likes.txt  1163  18.76     0.0   49.18
#
#      Dic  Sixltr  funct  pronoun  ppron     i    we   you  shehe  they  ipron  \
# 0  66.01   31.18  34.83     6.95   4.78  1.12  1.76  1.33   0.49  0.07   2.18
# 1  56.61   31.69  30.18     5.48   3.70  0.55  1.37  0.96   0.48  0.34   1.78
# 2  59.44   31.24  31.01     4.32   3.03  0.68  1.29  0.68   0.30  0.08   1.29
# 3  65.36   30.64  35.66     6.58   4.81  0.34  2.17  1.83   0.27  0.20   1.76
# 4  60.19   30.87  31.30     4.90   3.10  0.52  1.20  0.77   0.26  0.34   1.81
#
#    article  verb  auxverb  past  present  future  adverb  preps  conj  negate  \
# 0     6.18  6.25     3.79  0.28     5.41    0.21    1.54  11.73  3.23    0.14
# 1     4.79  4.79     3.22  0.34     3.70    0.68    1.37  11.02  2.94    0.48
# 2     5.99  4.32     2.88  0.08     4.17    0.08    1.06  11.60  2.81    0.23
# 3     6.10  6.31     4.20  0.75     5.02    0.34    2.24  12.47  3.46    0.27
# 4     5.50  5.07     3.01  0.26     4.64    0.17    1.55  12.30  2.58    0.26
#
#    quant  number  swear  social  family  friend  humans  affect  posemo  \
# 0   4.71    2.18    0.0    9.06    0.00    0.28    0.77    5.34    4.92
# 1   4.72    2.40    0.0    7.60    0.14    0.07    0.48    3.56    3.15
# 2   4.85    3.64    0.0    7.58    0.08    0.15    0.61    5.38    5.08
# 3   3.39    2.24    0.0    9.63    0.00    0.27    0.41    5.08    4.81
# 4   5.25    2.75    0.0    6.19    0.09    0.17    0.34    3.53    3.01
#
#    negemo   anx  anger   sad  cogmech  insight  cause  discrep  tentat  \
# 0    0.42  0.07   0.21  0.07     9.83     1.05   1.33     0.56    1.12
# 1    0.41  0.14   0.07  0.07     9.45     1.16   1.10     0.41    0.68
# 2    0.15  0.15   0.00  0.00     8.87     0.91   1.06     0.30    0.83
# 3    0.34  0.07   0.07  0.20    10.71     1.49   1.56     0.54    0.61
# 4    0.43  0.09   0.17  0.17    10.40     0.95   1.03     0.34    0.86
#
#    certain  inhib  incl  excl  percept   see  hear  feel   bio  body  health  \
# 0     1.33   0.28  3.79  0.56     1.83  0.56  0.63  0.49  0.70  0.21    0.14
# 1     1.30   0.41  3.49  0.68     0.75  0.34  0.21  0.00  1.10  0.34    0.27
# 2     1.06   0.30  3.71  0.76     1.97  0.76  0.68  0.23  1.21  0.53    0.23
# 3     0.95   0.20  4.47  0.47     1.83  0.47  0.34  0.81  0.68  0.27    0.20
# 4     1.29   0.34  3.78  0.69     1.46  0.69  0.34  0.34  0.60  0.09    0.17
#
#    sexual  ingest  relativ  motion  space  time  work  achieve  leisure  home  \
# 0    0.21    0.14    10.25    1.76   5.20  3.37  3.93     2.32     3.51  0.42
# 1    0.14    0.34     7.80    1.30   4.11  2.40  4.24     2.40     3.29  0.41
# 2    0.00    0.45     7.81    1.36   4.17  1.97  4.78     2.35     5.23  0.15
# 3    0.07    0.14    11.19    1.63   6.71  2.64  6.44     2.92     1.15  0.34
# 4    0.34    0.00    10.66    1.89   6.10  2.58  4.47     1.72     3.70  0.34
#
#    money  relig  death  assent  nonfl  filler  Unnamed: 71  Benevolence  \
# 0   1.97   0.56   0.14    0.00   0.00    0.42          NaN          1.0
# 1   1.03   0.27   0.00    0.07   0.00    0.14          NaN          0.8
# 2   0.99   0.30   0.00    0.08   0.08    0.15          NaN          1.0
# 3   1.02   0.20   0.00    0.14   0.00    0.20          NaN          0.6
# 4   1.03   0.43   0.00    0.00   0.00    0.34          NaN          0.9
#
#    Universal  Self-direction  Stimulation  Hedonism  Achievement   Power  \
# 0      1.000             1.0          0.9       0.9           0.9    0.4
# 1      0.800             0.7          0.6       0.4           0.6    0.5
# 2      0.733             0.6          1.0       0.7           0.9    1.0
# 3      1.000             0.8          0.7       0.5           0.4    0.2
# 4      0.867             0.9          0.9       0.6           0.9    0.4
#
#    Security  Conformity  Tradition
# 0       0.8         0.9        1.0
# 1       0.7         0.8        0.7
# 2       1.0         0.9        0.9
# 3       0.5         0.6        0.9
# 4       0.8         0.9        0.8

# %%
df.shape
# Out:
# (251, 82)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 251 entries, 0 to 250
# Data columns (total 82 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Filename        251 non-null    object
#  1   WC              251 non-null    int64
#  2   WPS             251 non-null    float64
#  3   Qmarks          251 non-null    float64
#  4   Unique          251 non-null    float64
#  5   Dic             251 non-null    float64
#  6   Sixltr          251 non-null    float64
#  7   funct           251 non-null    float64
#  8   pronoun         251 non-null    float64
#  9   ppron           251 non-null    float64
#  10  i               251 non-null    float64
#  11  we              251 non-null    float64
#  12  you             251 non-null    float64
#  13  shehe           251 non-null    float64
#  14  they            251 non-null    float64
#  15  ipron           251 non-null    float64
#  16  article         251 non-null    float64
#  17  verb            251 non-null    float64
#  18  auxverb         251 non-null    float64
#  19  past            251 non-null    float64
#  20  present         251 non-null    float64
#  21  future          251 non-null    float64
#  22  adverb          251 non-null    float64
#  23  preps           251 non-null    float64
#  24  conj            251 non-null    float64
#  25  negate          251 non-null    float64
#  26  quant           251 non-null    float64
#  27  number          251 non-null    float64
#  28  swear           251 non-null    float64
#  29  social          251 non-null    float64
#  30  family          251 non-null    float64
#  31  friend          251 non-null    float64
#  32  humans          251 non-null    float64
#  33  affect          251 non-null    float64
#  34  posemo          251 non-null    float64
#  35  negemo          251 non-null    float64
#  36  anx             251 non-null    float64
#  37  anger           251 non-null    float64
#  38  sad             251 non-null    float64
#  39  cogmech         251 non-null    float64
#  40  insight         251 non-null    float64
#  41  cause           251 non-null    float64
#  42  discrep         251 non-null    float64
#  43  tentat          251 non-null    float64
#  44  certain         251 non-null    float64
#  45  inhib           251 non-null    float64
#  46  incl            251 non-null    float64
#  47  excl            251 non-null    float64
#  48  percept         251 non-null    float64
#  49  see             251 non-null    float64
#  50  hear            251 non-null    float64
#  51  feel            251 non-null    float64
#  52  bio             251 non-null    float64
#  53  body            251 non-null    float64
#  54  health          251 non-null    float64
#  55  sexual          251 non-null    float64
#  56  ingest          251 non-null    float64
#  57  relativ         251 non-null    float64
#  58  motion          251 non-null    float64
#  59  space           251 non-null    float64
#  60  time            251 non-null    float64
#  61  work            251 non-null    float64
#  62  achieve         251 non-null    float64
#  63  leisure         251 non-null    float64
#  64  home            251 non-null    float64
#  65  money           251 non-null    float64
#  66  relig           251 non-null    float64
#  67  death           251 non-null    float64
#  68  assent          251 non-null    float64
#  69  nonfl           251 non-null    float64
#  70  filler          251 non-null    float64
#  71  Unnamed: 71     0 non-null      float64
#  72  Benevolence     251 non-null    float64
#  73  Universal       251 non-null    float64
#  74  Self-direction  251 non-null    float64
#  75  Stimulation     251 non-null    float64
#  76  Hedonism        251 non-null    float64
#  77  Achievement     251 non-null    float64
#  78  Power           251 non-null    float64
#  79  Security        251 non-null    float64
#  80  Conformity      251 non-null    float64
#  81  Tradition       251 non-null    float64
# dtypes: float64(80), int64(1), object(1)
# memory usage: 160.9+ KB

# %%
df.drop('Unnamed: 71', axis=1, inplace=True)

# %%
df.shape
# Out:
# (251, 81)

# %%
df.isnull().sum()
# Out:
# Filename        0
# WC              0
# WPS             0
# Qmarks          0
# Unique          0
#                ..
# Achievement     0
# Power           0
# Security        0
# Conformity      0
# Tradition       0
# Length: 81, dtype: int64

# %%
df_big5 = pd.read_excel('Data.xlsx')

# %%
df_big5.head()
# Out:
#                                    Filename  Openness  Conscientiousness  \
# 0  A M Tauhidul Karim Drubo_AIUB_status.txt     0.625              0.889
# 1            Abhijit Mondal_AIUB_status.txt     0.700              0.722
# 2             abhishek Saha_AIUB_status.txt     0.650              0.389
# 3    Abir Md Moshiur Rahman_AIUB_status.txt     0.750              0.611
# 4         abir Tanzin Adnan_AIUB_status.txt     0.650              0.667
#
#    Extraversion  Agreeableness  Neuroticism Gender
# 0         0.469          0.750        0.375      m
# 1         0.531          0.694        0.469      m
# 2         0.562          0.528        0.500      m
# 3         0.531          0.833        0.375      m
# 4         0.500          0.778        0.250      m

# %%
df_big5 = df_big5.dropna()

# %%
df_big5.isnull().sum()
# Out:
# Filename             0
# Openness             0
# Conscientiousness    0
# Extraversion         0
# Agreeableness        0
# Neuroticism          0
# Gender               0
# dtype: int64

# %%
df_big5.shape
# Out:
# (163, 7)

# %%
# Statistics Analysis for df_big5 dataframe
summary_df_big5 = df_big5.describe()
summary_df_big5.loc['median'] = df_big5.median()
summary_df_big5.loc['skewness'] = df_big5.skew()
summary_df_big5.loc['kurtosis'] = df_big5.kurt()
summary_df_big5.loc['variance'] = df_big5.var()
summary_df_big5.loc['mad'] = df_big5.mad()
summary_df_big5.round(decimals= 3)
# Out:
#           Openness  Conscientiousness  Extraversion  Agreeableness  \
# count      163.000            163.000       163.000        163.000
# mean         0.633              0.573         0.518          0.647
# std          0.094              0.144         0.098          0.102
# min          0.375              0.194         0.156          0.361
# 25%          0.575              0.472         0.469          0.583
# 50%          0.650              0.583         0.500          0.639
# 75%          0.700              0.667         0.594          0.694
# max          0.875              0.917         0.750          0.944
# median       0.650              0.583         0.500          0.639
# skewness    -0.283             -0.028        -0.206          0.053
# kurtosis    -0.016             -0.318         0.761          0.046
# variance     0.009              0.021         0.010          0.010
# mad          0.074              0.116         0.076          0.080
#
#           Neuroticism
# count         163.000
# mean            0.477
# std             0.166
# min             0.125
# 25%             0.375
# 50%             0.469
# 75%             0.562
# max             0.906
# median          0.469
# skewness        0.362
# kurtosis       -0.215
# variance        0.028
# mad             0.130

# %% [markdown]
# ## Outliers

# %%
df.shape
# Out:
# (251, 81)

# %%
df2 = df.drop('Filename', axis=1)
z_scores = np.abs((df2 - df2.mean()) / df2.std())

# Set the threshold for outliers
threshold = 3

# Find the outliers in each column
outliers = z_scores > threshold

# Print the outliers
outliers.head(10)
# Out:
#       WC    WPS  Qmarks  Unique    Dic  Sixltr  funct  pronoun  ppron      i  \
# 0  False  False   False   False  False   False  False    False  False  False
# 1  False  False   False   False  False   False  False    False  False  False
# 2  False  False   False   False  False   False  False    False  False  False
# 3  False  False   False   False  False   False  False    False  False  False
# 4  False  False   False   False  False   False  False    False  False  False
# 5  False  False   False   False  False   False  False    False  False  False
# 6  False  False   False   False  False   False  False    False  False  False
# 7  False  False   False   False  False   False  False    False  False  False
# 8  False  False   False   False  False   False  False    False  False  False
# 9  False  False   False   False  False   False  False    False  False  False
#
#       we    you  shehe   they  ipron  article   verb  auxverb   past  present  \
# 0  False  False  False  False  False    False  False    False  False    False
# 1  False  False  False  False  False    False  False    False  False    False
# 2  False  False  False  False  False    False  False    False  False    False
# 3  False  False  False  False  False    False  False    False  False    False
# 4  False  False  False  False  False    False  False    False  False    False
# 5  False  False  False  False  False    False  False    False  False    False
# 6  False  False  False  False  False    False  False    False  False    False
# 7  False  False  False  False  False    False  False    False  False    False
# 8  False  False  False  False  False    False  False    False  False    False
# 9  False  False  False  False  False    False  False    False  False    False
#
#    future  adverb  preps   conj  negate  quant  number  swear  social  family  \
# 0   False   False  False  False   False  False   False  False   False   False
# 1   False   False  False  False   False  False   False  False   False   False
# 2   False   False  False  False   False  False   False  False   False   False
# 3   False   False  False  False   False  False   False  False   False   False
# 4   False   False  False  False   False  False   False  False   False   False
# 5   False   False  False  False   False  False   False  False   False   False
# 6   False   False  False  False   False  False   False  False   False   False
# 7   False   False  False  False   False  False   False  False   False   False
# 8   False   False  False  False   False  False   False  False   False   False
# 9   False   False  False  False   False  False   False  False   False   False
#
#    friend  humans  affect  posemo  negemo    anx  anger    sad  cogmech  \
# 0   False   False   False   False   False  False  False  False    False
# 1   False   False   False   False   False  False  False  False    False
# 2   False   False   False   False   False  False  False  False    False
# 3   False   False   False   False   False  False  False  False    False
# 4   False   False   False   False   False  False  False  False    False
# 5   False   False   False   False   False  False  False  False    False
# 6   False   False   False   False   False  False  False  False    False
# 7   False   False   False   False   False  False  False  False    False
# 8   False   False   False   False   False  False  False  False    False
# 9   False   False   False   False   False  False  False  False    False
#
#    insight  cause  discrep  tentat  certain  inhib   incl   excl  percept  \
# 0    False  False    False   False    False  False  False  False    False
# 1    False  False    False   False    False  False  False  False    False
# 2    False  False    False   False    False  False  False  False    False
# 3    False  False    False   False    False  False  False  False    False
# 4    False  False    False   False    False  False  False  False    False
# 5    False  False    False   False    False  False  False  False    False
# 6    False  False    False   False    False  False  False  False    False
# 7    False  False    False   False    False  False  False  False    False
# 8    False  False    False   False    False  False  False  False    False
# 9    False  False    False   False    False  False  False  False    False
#
#      see   hear   feel    bio   body  health  sexual  ingest  relativ  motion  \
# 0  False  False  False  False  False   False   False   False    False   False
# 1  False  False  False  False  False   False   False   False    False   False
# 2  False  False  False  False  False   False   False   False    False   False
# 3  False  False  False  False  False   False   False   False    False   False
# 4  False  False  False  False  False   False   False   False    False   False
# 5  False  False  False  False  False   False   False   False    False   False
# 6  False  False  False  False  False   False   False   False    False   False
# 7  False  False  False  False  False   False   False   False    False   False
# 8  False  False  False  False  False   False   False   False    False   False
# 9  False  False  False  False  False   False   False   False    False   False
#
#    space   time   work  achieve  leisure   home  money  relig  death  assent  \
# 0  False  False  False    False    False  False  False  False  False   False
# 1  False  False  False    False    False  False  False  False  False   False
# 2  False  False  False    False    False  False  False  False  False   False
# 3  False  False  False    False    False  False  False  False  False   False
# 4  False  False  False    False    False  False  False  False  False   False
# 5  False  False  False    False    False  False  False  False  False   False
# 6  False  False  False    False    False  False  False  False  False   False
# 7  False  False  False    False    False  False  False  False  False   False
# 8  False  False  False    False    False  False  False  False  False   False
# 9  False  False  False    False    False  False  False  False  False   False
#
#    nonfl  filler  Benevolence  Universal  Self-direction  Stimulation  \
# 0  False   False        False      False           False        False
# 1  False   False        False      False           False        False
# 2  False   False        False      False           False        False
# 3  False   False        False      False           False        False
# 4  False   False        False      False           False        False
# 5  False   False        False      False           False        False
# 6  False   False        False      False           False        False
# 7  False   False        False      False           False        False
# 8  False   False        False      False           False        False
# 9  False   False        False      False           False        False
#
#    Hedonism  Achievement   Power  Security  Conformity  Tradition
# 0     False         False  False     False       False      False
# 1     False         False  False     False       False      False
# 2     False         False  False     False       False      False
# 3     False         False  False     False       False      False
# 4     False         False  False     False       False      False
# 5     False         False  False     False       False      False
# 6     False         False  False     False       False      False
# 7     False         False  False     False       False      False
# 8     False         False  False     False       False      False
# 9     False         False  False     False       False      False

# %%
total_outliers = outliers.sum()
total_outliers = pd.DataFrame(total_outliers)
print('Total Outliers:')
total_outliers.transpose()
# Out:
# Total Outliers:
#    WC  WPS  Qmarks  Unique  Dic  Sixltr  funct  pronoun  ppron  i  we  you  \
# 0   8    4       4       3    3       1      2        2      2  2   1    1
#
#    shehe  they  ipron  article  verb  auxverb  past  present  future  adverb  \
# 0      3     3      3        1     4        3     2        2       2       2
#
#    preps  conj  negate  quant  number  swear  social  family  friend  humans  \
# 0      1     2       5      2       3      8       1       3       3       1
#
#    affect  posemo  negemo  anx  anger  sad  cogmech  insight  cause  discrep  \
# 0       3       3       5    3      5    4        3        2      3        3
#
#    tentat  certain  inhib  incl  excl  percept  see  hear  feel  bio  body  \
# 0       3        2      3     2     3        3    3     4     3    4     4
#
#    health  sexual  ingest  relativ  motion  space  time  work  achieve  \
# 0       1       3       5        2       2      1     4     3        4
#
#    leisure  home  money  relig  death  assent  nonfl  filler  Benevolence  \
# 0        3     3      2      4      4       3      4       3            1
#
#    Universal  Self-direction  Stimulation  Hedonism  Achievement   Power  \
# 0          2               1            2         1             1      0
#
#    Security  Conformity  Tradition
# 0         3           0          3

# %% [markdown]
# ## Outliers for df_big5

# %%
new_df = df_big5.drop('Filename', axis=1)
z_scores = np.abs((new_df - new_df.mean()) / new_df.std())

# Set the threshold for outliers
threshold = 3

# Find the outliers in each column
outliers = z_scores > threshold

# outliers
total_outliers = outliers.sum()
total_outliers = pd.DataFrame(total_outliers)
print('Total Outliers of Big5:')
total_outliers.transpose()
# Out:
# Total Outliers of Big5:
#    Agreeableness  Conscientiousness  Extraversion  Gender  Neuroticism  \
# 0              0                  0             1       0            0
#
#    Openness
# 0         0

# %% [markdown]
# ## Merging two dataframes

# %%
df['First Name'] = df['Filename'].str.split('.').str[0]
df['Name'] = df['First Name'].str.replace('_likes', '')
df.drop('First Name', axis=1, inplace=True)
df.shape
# Out:
# (251, 82)

# %%
df_big5.head()
# Out:
#                                    Filename  Openness  Conscientiousness  \
# 0  A M Tauhidul Karim Drubo_AIUB_status.txt     0.625              0.889
# 1            Abhijit Mondal_AIUB_status.txt     0.700              0.722
# 2             abhishek Saha_AIUB_status.txt     0.650              0.389
# 3    Abir Md Moshiur Rahman_AIUB_status.txt     0.750              0.611
# 4         abir Tanzin Adnan_AIUB_status.txt     0.650              0.667
#
#    Extraversion  Agreeableness  Neuroticism Gender
# 0         0.469          0.750        0.375      m
# 1         0.531          0.694        0.469      m
# 2         0.562          0.528        0.500      m
# 3         0.531          0.833        0.375      m
# 4         0.500          0.778        0.250      m

# %%
df_big5['First Name'] = df_big5['Filename'].str.split('.').str[0]
df_big5['Name'] = df_big5['First Name'].str.replace('_status', '')
df_big5.drop('First Name', axis=1, inplace=True)
df_big5.head()
# Out:
#                                    Filename  Openness  Conscientiousness  \
# 0  A M Tauhidul Karim Drubo_AIUB_status.txt     0.625              0.889
# 1            Abhijit Mondal_AIUB_status.txt     0.700              0.722
# 2             abhishek Saha_AIUB_status.txt     0.650              0.389
# 3    Abir Md Moshiur Rahman_AIUB_status.txt     0.750              0.611
# 4         abir Tanzin Adnan_AIUB_status.txt     0.650              0.667
#
#    Extraversion  Agreeableness  Neuroticism Gender  \
# 0         0.469          0.750        0.375      m
# 1         0.531          0.694        0.469      m
# 2         0.562          0.528        0.500      m
# 3         0.531          0.833        0.375      m
# 4         0.500          0.778        0.250      m
#
#                             Name
# 0  A M Tauhidul Karim Drubo_AIUB
# 1            Abhijit Mondal_AIUB
# 2             abhishek Saha_AIUB
# 3    Abir Md Moshiur Rahman_AIUB
# 4         abir Tanzin Adnan_AIUB

# %%
merged_df = pd.merge(df_big5, df, on='Name')

# %%
merged_df.drop(['Filename_x', 'Filename_y'], axis=1, inplace=True)

# %%
cols = merged_df.columns.tolist()
cols = [cols[6]] + cols[0:6] + cols[7:]
merged_df = merged_df[cols]

# %%
merged_df.shape
# Out:
# (157, 87)

# %%
merged_df.head()
# Out:
#                             Name  Openness  Conscientiousness  Extraversion  \
# 0  A M Tauhidul Karim Drubo_AIUB     0.625              0.889         0.469
# 1            Abhijit Mondal_AIUB     0.700              0.722         0.531
# 2             abhishek Saha_AIUB     0.650              0.389         0.562
# 3    Abir Md Moshiur Rahman_AIUB     0.750              0.611         0.531
# 4         abir Tanzin Adnan_AIUB     0.650              0.667         0.500
#
#    Agreeableness  Neuroticism Gender    WC    WPS  Qmarks  Unique    Dic  \
# 0          0.750        0.375      m  1424  16.56     0.0   49.37  66.01
# 1          0.694        0.469      m  1475  16.39     0.0   48.34  65.36
# 2          0.528        0.500      m  1163  18.76     0.0   49.18  60.19
# 3          0.833        0.375      m  1374  17.17     0.0   52.84  63.76
# 4          0.778        0.250      m  1175  15.06     0.0   53.87  61.87
#
#    Sixltr  funct  pronoun  ppron     i    we   you  shehe  they  ipron  \
# 0   31.18  34.83     6.95   4.78  1.12  1.76  1.33   0.49  0.07   2.18
# 1   30.64  35.66     6.58   4.81  0.34  2.17  1.83   0.27  0.20   1.76
# 2   30.87  31.30     4.90   3.10  0.52  1.20  0.77   0.26  0.34   1.81
# 3   30.42  33.62     6.11   3.64  0.66  1.75  1.02   0.07  0.15   2.47
# 4   31.06  32.26     5.28   3.40  0.26  1.70  1.11   0.34  0.00   1.87
#
#    article  verb  auxverb  past  present  future  adverb  preps  conj  negate  \
# 0     6.18  6.25     3.79  0.28     5.41    0.21    1.54  11.73  3.23    0.14
# 1     6.10  6.31     4.20  0.75     5.02    0.34    2.24  12.47  3.46    0.27
# 2     5.50  5.07     3.01  0.26     4.64    0.17    1.55  12.30  2.58    0.26
# 3     4.80  6.70     4.44  0.36     5.75    0.44    1.60  10.19  3.13    0.36
# 4     5.79  5.02     3.66  0.09     4.60    0.17    1.02  11.23  3.23    0.43
#
#    quant  number  swear  social  family  friend  humans  affect  posemo  \
# 0   4.71    2.18   0.00    9.06    0.00    0.28    0.77    5.34    4.92
# 1   3.39    2.24   0.00    9.63    0.00    0.27    0.41    5.08    4.81
# 2   5.25    2.75   0.00    6.19    0.09    0.17    0.34    3.53    3.01
# 3   4.66    3.57   0.07    7.57    0.07    0.22    0.44    4.95    4.22
# 4   4.68    2.47   0.00    6.55    0.09    0.17    0.77    5.02    4.60
#
#    negemo   anx  anger   sad  cogmech  insight  cause  discrep  tentat  \
# 0    0.42  0.07   0.21  0.07     9.83     1.05   1.33     0.56    1.12
# 1    0.34  0.07   0.07  0.20    10.71     1.49   1.56     0.54    0.61
# 2    0.43  0.09   0.17  0.17    10.40     0.95   1.03     0.34    0.86
# 3    0.73  0.07   0.22  0.29    11.35     1.31   1.75     0.29    1.16
# 4    0.43  0.09   0.26  0.09     9.79     1.96   1.28     0.34    1.62
#
#    certain  inhib  incl  excl  percept   see  hear  feel   bio  body  health  \
# 0     1.33   0.28  3.79  0.56     1.83  0.56  0.63  0.49  0.70  0.21    0.14
# 1     0.95   0.20  4.47  0.47     1.83  0.47  0.34  0.81  0.68  0.27    0.20
# 2     1.29   0.34  3.78  0.69     1.46  0.69  0.34  0.34  0.60  0.09    0.17
# 3     1.38   0.51  4.37  0.44     1.02  0.36  0.44  0.15  1.24  0.36    0.36
# 4     0.77   0.68  2.89  0.85     1.45  0.60  0.09  0.43  0.77  0.17    0.09
#
#    sexual  ingest  relativ  motion  space  time  work  achieve  leisure  home  \
# 0    0.21    0.14    10.25    1.76   5.20  3.37  3.93     2.32     3.51  0.42
# 1    0.07    0.14    11.19    1.63   6.71  2.64  6.44     2.92     1.15  0.34
# 2    0.34    0.00    10.66    1.89   6.10  2.58  4.47     1.72     3.70  0.34
# 3    0.29    0.36    10.12    1.09   5.68  2.91  4.66     3.20     3.13  0.44
# 4    0.17    0.34     8.60    1.11   4.43  3.15  4.94     2.98     2.30  0.60
#
#    money  relig  death  assent  nonfl  filler  Benevolence  Universal  \
# 0   1.97   0.56   0.14    0.00   0.00    0.42          1.0      1.000
# 1   1.02   0.20   0.00    0.14   0.00    0.20          0.6      1.000
# 2   1.03   0.43   0.00    0.00   0.00    0.34          0.9      0.867
# 3   1.82   0.66   0.00    0.00   0.00    0.22          0.9      0.667
# 4   0.94   0.43   0.00    0.00   0.17    0.51          0.9      0.733
#
#    Self-direction  Stimulation  Hedonism  Achievement   Power  Security  \
# 0             1.0          0.9       0.9           0.9    0.4       0.8
# 1             0.8          0.7       0.5           0.4    0.2       0.5
# 2             0.9          0.9       0.6           0.9    0.4       0.8
# 3             0.4          0.3       0.6           0.8    0.6       0.7
# 4             0.9          0.8       0.8           0.7    0.4       0.6
#
#    Conformity  Tradition
# 0         0.9        1.0
# 1         0.6        0.9
# 2         0.9        0.8
# 3         0.4        0.9
# 4         0.8        1.0

# %%
cols_to_keep = ['Openness', 'Conscientiousness', 'Extraversion', 'Agreeableness', 'Neuroticism']
new_df = merged_df[cols_to_keep].copy()
des = new_df.describe()

# %% [markdown]
# ## Machine Learning Model

# %% [markdown]
# **Big5 Personality Traits Prediction with Machine Learning Classification**

# %%
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier 
from sklearn import tree
from sklearn.metrics import accuracy_score
from matplotlib import pyplot as plt
import seaborn as sns

# %%
openness_df= merged_df
openness_df.drop(columns=['Conscientiousness','Extraversion', 'Agreeableness', 'Neuroticism','Gender','Name'],inplace = True)
openness_df.head()
# Out:
#    Openness    WC    WPS  Qmarks  Unique    Dic  Sixltr  funct  pronoun  \
# 0     0.625  1424  16.56     0.0   49.37  66.01   31.18  34.83     6.95
# 1  2.64  6.44     2.92     1.15  0.34   1.02   0.20   0.00    0.14   0.00
# 2  2.58  4.47     1.72     3.70  0.34   1.03   0.43   0.00    0.00   0.00
# 3  2.91  4.66     3.20     3.13  0.44   1.82   0.66   0.00    0.00   0.00
# 4  3.15  4.94     2.98     2.30  0.60   0.94   0.43   0.00    0.00   0.17
#
#    filler  Benevolence  Universal  Self-direction  Stimulation  Hedonism  \
# 0    0.42          1.0      1.000             1.0          0.9       0.9
# 1    0.20          0.6      1.000             0.8          0.7       0.5
# 2    0.34          0.9      0.867             0.9          0.9       0.6
# 3    0.22          0.9      0.667             0.4          0.3       0.6
# 4    0.51          0.9      0.733             0.9          0.8       0.8
#
#    Achievement   Power  Security  Conformity  Tradition
# 0           0.9    0.4       0.8         0.9        1.0
# 1           0.4    0.2       0.5         0.6        0.9
# 2           0.9    0.4       0.8         0.9        0.8
# 3           0.8    0.6       0.7         0.4        0.9
# 4           0.7    0.4       0.6         0.8        1.0

# %%
plt.figure(figsize=(6,4))
sns.boxplot(data=openness_df['Openness']);

# %% [markdown]
# Convert Openness values into three categories according to quadratic values:

# %%
def get_category(val, q1, q3):
    if val > q3:
        return 'high'
    elif val < q1:
        return 'low'
    else:
        return 'medium'

q1 = openness_df['Openness'].quantile(0.25)
q3 = openness_df['Openness'].quantile(0.75)

openness_df['Openness_Category'] = openness_df['Openness'].apply(get_category, args=(q1, q3))
openness_df = openness_df.drop('Openness', axis=1)

# %%
openness_df
# Out:
#        WC    WPS  Qmarks  Unique    Dic  Sixltr  funct  pronoun  ppron     i  \
# 0    1424  16.56     0.0   49.37  66.01   31.18  34.83     6.95   4.78  1.12
# 1    1475  16.39     0.0   48.34  65.36   30.64  35.66     6.58   4.81  0.34
# 2    1163  18.76     0.0   49.18  60.19   30.87  31.30     4.90   3.10  0.52
# 3    1374  17.17     0.0   52.84  63.76   30.42  33.62     6.11   3.64  0.66
# 4    1175  15.06     0.0   53.87  61.87   31.06  32.26     5.28   3.40  0.26
# ..    ...    ...     ...     ...    ...     ...    ...      ...    ...   ...
# 152  1004  24.49     0.0   53.78  59.86   27.79  32.37     6.37   4.28  0.20
# 153  1337  17.83     0.0   47.12  65.00   28.20  35.60     7.03   4.34  0.30
# 154  1125  18.15     0.0   53.87  64.53   30.93  34.49     7.73   4.89  0.53
# 155  1142  17.04     0.0   48.51  57.97   32.31  28.90     4.03   2.63  0.26
# 156  1489  17.31     0.0   49.23  65.88   26.46  35.39     6.65   4.23  0.87
#
#        we   you  shehe  they  ipron  article  verb  auxverb  past  present  \
# 0    1.76  1.33   0.49  0.07   2.18     6.18  6.25     3.79  0.28     5.41
# 1    2.17  1.83   0.27  0.20   1.76     6.10  6.31     4.20  0.75     5.02
# 2    1.20  0.77   0.26  0.34   1.81     5.50  5.07     3.01  0.26     4.64
# 3    1.75  1.02   0.07  0.15   2.47     4.80  6.70     4.44  0.36     5.75
# 4    1.70  1.11   0.34  0.00   1.87     5.79  5.02     3.66  0.09     4.60
# ..    ...   ...    ...   ...    ...      ...   ...      ...   ...      ...
# 3            0.3       0.6           0.8    0.6       0.7         0.4
# 4            0.8       0.8           0.7    0.4       0.6         0.8
# ..           ...       ...           ...    ...       ...         ...
# 152          0.8       0.9           0.9    0.4       0.8         0.7
# 153          0.7       0.5           0.7    0.5       1.0         0.4
# 154          0.6       0.8           0.6    0.6       0.9         1.0
# 155          0.8       0.3           1.0    0.4       0.8         0.8
# 156          0.8       0.2           0.9    0.4       0.8         0.7
#
#      Tradition Openness_Category
# 0          1.0            medium
# 1          0.9            medium
# 2          0.8            medium
# 3          0.9              high
# 4          1.0            medium
# ..         ...               ...
# 152        0.7            medium
# 153        0.7              high
# 154        0.7              high
# 155        0.9            medium
# 156        0.6               low
#
# [157 rows x 81 columns]

# %%
# Checking balancing of data

sns.countplot(data=openness_df, x= 'Openness_Category');

# %% [markdown]
# Hence, data are not balanced here, we need to balance the data according to openness_category column. We will use SMOTE method of balancing here.

# %%
x = openness_df.drop('Openness_Category', axis=1)
y = openness_df[['Openness_Category']]

# %%
x
# Out:
#        WC    WPS  Qmarks  Unique    Dic  Sixltr  funct  pronoun  ppron     i  \
# 0    1424  16.56     0.0   49.37  66.01   31.18  34.83     6.95   4.78  1.12
# 1    1475  16.39     0.0   48.34  65.36   30.64  35.66     6.58   4.81  0.34
# 2    1163  18.76     0.0   49.18  60.19   30.87  31.30     4.90   3.10  0.52
# 3    1374  17.17     0.0   52.84  63.76   30.42  33.62     6.11   3.64  0.66
# 4    1175  15.06     0.0   53.87  61.87   31.06  32.26     5.28   3.40  0.26
# ..    ...    ...     ...     ...    ...     ...    ...      ...    ...   ...
# 152  1004  24.49     0.0   53.78  59.86   27.79  32.37     6.37   4.28  0.20
# 153  1337  17.83     0.0   47.12  65.00   28.20  35.60     7.03   4.34  0.30
# 154  1125  18.15     0.0   53.87  64.53   30.93  34.49     7.73   4.89  0.53
# 155  1142  17.04     0.0   48.51  57.97   32.31  28.90     4.03   2.63  0.26
# 156  1489  17.31     0.0   49.23  65.88   26.46  35.39     6.65   4.23  0.87
#
#        we   you  shehe  they  ipron  article  verb  auxverb  past  present  \
# 0    1.76  1.33   0.49  0.07   2.18     6.18  6.25     3.79  0.28     5.41
# 1    2.17  1.83   0.27  0.20   1.76     6.10  6.31     4.20  0.75     5.02
# 2    1.20  0.77   0.26  0.34   1.81     5.50  5.07     3.01  0.26     4.64
# 3    1.75  1.02   0.07  0.15   2.47     4.80  6.70     4.44  0.36     5.75
# 4    1.70  1.11   0.34  0.00   1.87     5.79  5.02     3.66  0.09     4.60
# ..    ...   ...    ...   ...    ...      ...   ...      ...   ...      ...
# 152  2.09  1.69   0.30  0.00   2.09     4.48  5.08     3.09  0.30     4.58
# 153  1.35  2.24   0.45  0.00   2.69     5.98  6.06     4.34  0.22     5.16
# 154  2.49  1.87   0.00  0.00   2.84     4.36  6.40     4.27  0.09     5.78
# 155  1.40  0.79   0.18  0.00   1.40     5.43  4.73     3.24  0.44     4.12
# 156  1.48  1.14   0.34  0.40   2.42     5.98  7.05     4.30  0.81     5.64
#
# 0          1.0
# 1          0.9
# 2          0.8
# 3          0.9
# 4          1.0
# ..         ...
# 152        0.7
# 153        0.7
# 154        0.7
# 155        0.9
# 156        0.6
#
# [157 rows x 80 columns]

# %%
y
# Out:
#     Openness_Category
# 0              medium
# 1              medium
# 2              medium
# 3                high
# 4              medium
# ..                ...
# 152            medium
# 153              high
# 154              high
# 155            medium
# 156               low
#
# [157 rows x 1 columns]

# %% [markdown]
# ##### Synthetic Minority Oversampling Tenique (SMOTETomek)

# %%
from imblearn.combine import SMOTETomek
sm = SMOTETomek(random_state= 42)
X_new, y_new = sm.fit_resample(x, y)

# %%
X_new.shape
# Out:
# (233, 80)

# %%
y_new.shape
# Out:
# (233, 1)

# %%
sns.countplot(data=y_new, x= 'Openness_Category');

# %%
y_new['Openness_Category'].value_counts()
# Out:
# low       87
# high      75
# medium    71
# Name: Openness_Category, dtype: int64

# %% [markdown]
# ### Feature Engineering

# %% [markdown]
# #### Extra Tree Classifier

# %%
from sklearn.ensemble import ExtraTreesClassifier
extra_clf = ExtraTreesClassifier()
extra_clf.fit(x, y)
feature_importance = extra_clf.feature_importances_
feature_importance
# Out:
# array([0.00857441, 0.0113148 , 0.        , 0.01861817, 0.01347084,
#        0.01038657, 0.01499558, 0.01411464, 0.01096683, 0.01479699,
#        0.01064467, 0.01057966, 0.01013951, 0.01254066, 0.01018165,
#        0.00989877, 0.01270271, 0.01241933, 0.01607227, 0.01159435,
#        0.01483441, 0.01323385, 0.01264754, 0.01077395, 0.01131064,
#        0.01065751, 0.01258758, 0.00980269, 0.01155219, 0.01191815,
#        0.00982601, 0.01208489, 0.01244877, 0.01396548, 0.01033216,
#        0.01024473, 0.01117481, 0.01582726, 0.01226383, 0.01194098,
#        0.01385213, 0.0135127 , 0.01026167, 0.01276763, 0.01535261,
#        0.0087738 , 0.01217967, 0.01112203, 0.01136842, 0.02425944,
#        0.00959513, 0.01022486, 0.01013858, 0.01328028, 0.01469912,
#        0.0117258 , 0.00993175, 0.01174896, 0.01054431, 0.01207266,
#        0.0115736 , 0.01105355, 0.01040947, 0.01688702, 0.01157766,
#        0.01761848, 0.01292806, 0.00998926, 0.00935175, 0.01248367,
#        0.01411144, 0.01341683, 0.02759966, 0.01237906, 0.01374636,
#        0.00982266, 0.0151949 , 0.00825064, 0.02615569, 0.01459882])

# %%
imp = pd.DataFrame(feature_importance, columns = ['feature_score'])
imp
# Out:
#     feature_score
# 0        0.008574
# 1        0.011315
# 2        0.000000
# 3        0.018618
# 4        0.013471
# ..            ...
# 75       0.009823
# 76       0.015195
# 77       0.008251
# 78       0.026156
# 79       0.014599
#
# [80 rows x 1 columns]

# %%
X_new.columns
cols = pd.DataFrame(x.columns, columns = ['feature_names'])
gains = pd.concat([cols, imp], axis=1)
gains
# Out:
#    feature_names  feature_score
# 0             WC       0.008574
# 1            WPS       0.011315
# 2         Qmarks       0.000000
# 3         Unique       0.018618
# 4            Dic       0.013471
# ..           ...            ...
# 75  Achievement        0.009823
# 76         Power       0.015195
# 77      Security       0.008251
# 78    Conformity       0.026156
# 79     Tradition       0.014599
#
# [80 rows x 2 columns]

# %%
# Sort all with respect to gain_score
gains.nlargest(gains.shape[0], 'feature_score')
# Out:
#      feature_names  feature_score
# 72  Self-direction       0.027600
# 78      Conformity       0.026156
# 49            hear       0.024259
# 3           Unique       0.018618
# 65           relig       0.017618
# ..             ...            ...
# 68           nonfl       0.009352
# 45            incl       0.008774
# 0               WC       0.008574
# 77        Security       0.008251
# 2           Qmarks       0.000000
#
# [80 rows x 2 columns]

# %%
gains_all = gains.nlargest(gains.shape[0], 'feature_score')

# %%
features = pd.Series(feature_importance, index = x.columns)
plt.figure(figsize= (18,6));
features.nlargest(features.shape[0]).plot(kind = 'bar');

# %%
features = pd.Series(feature_importance, index = x.columns)
plt.figure(figsize= (18,6));
features.nlargest(27).plot(kind = 'bar');

# %%
most_gains = gains.nlargest(27, 'feature_score')
most_gains
# Out:
#      feature_names  feature_score
# 72  Self-direction       0.027600
# 78      Conformity       0.026156
# 49            hear       0.024259
# 3           Unique       0.018618
# 65           relig       0.017618
# 63            home       0.016887
# 18            past       0.016072
# 37             sad       0.015827
# 44           inhib       0.015353
# 76           Power       0.015195
# 6            funct       0.014996
# 20          future       0.014834
# 9                i       0.014797
# 54          sexual       0.014699
# 79       Tradition       0.014599
# 7          pronoun       0.014115
# 70     Benevolence       0.014111
# 33          posemo       0.013965
# 40           cause       0.013852
# 74        Hedonism       0.013746
# 41         discrep       0.013513
# 4              Dic       0.013471
# 71       Universal       0.013417
# 53          health       0.013280
# 21          adverb       0.013234
# 66           death       0.012928
# 43         certain       0.012768

# %%
X_new = X_new[most_gains.feature_names]
# most_gains.feature_names

# %%
X_new.head()
# Out:
#    Self-direction  Conformity  hear  Unique  relig  home  past   sad  inhib  \
# 0             1.0         0.9  0.63   49.37   0.56  0.42  0.28  0.07   0.28
# 1             0.8         0.6  0.34   48.34   0.20  0.34  0.75  0.20   0.20
# 2             0.4         0.4  0.44   52.84   0.66  0.44  0.36  0.29   0.51
# 3             0.9         0.8  0.09   53.87   0.43  0.60  0.09  0.09   0.68
# 4             0.8         0.7  0.85   51.87   0.48  0.24  0.12  0.24   0.73
#
#    Power  funct  future     i  sexual  Tradition  pronoun  Benevolence  \
# 0    0.4  34.83    0.21  1.12    0.21        1.0     6.95          1.0
# 1    0.2  35.66    0.34  0.34    0.07        0.9     6.58          0.6
# 2    0.6  33.62    0.44  0.66    0.29        0.9     6.11          0.9
# 3    0.4  32.26    0.17  0.26    0.17        1.0     5.28          0.9
# 4    0.9  30.23    0.24  0.36    0.00        1.0     4.96          0.9
#
#    posemo  cause  Hedonism  discrep    Dic  Universal  health  adverb  death  \
# 0    4.92   1.33       0.9     0.56  66.01      1.000    0.14    1.54   0.14
# 1    4.81   1.56       0.5     0.54  65.36      1.000    0.20    2.24   0.00
# 2    4.22   1.75       0.6     0.29  63.76      0.667    0.36    1.60   0.00
# 3    4.60   1.28       0.8     0.34  61.87      0.733    0.09    1.02   0.00
# 4    4.47   0.36       0.7     0.48  61.55      0.533    0.24    1.33   0.00
#
#    certain
# 0     1.33
# 1     0.95
# 2     1.38
# 3     0.77
# 4     1.21

# %%
X_new.shape
# Out:
# (233, 27)

# %%
y_new.shape
# Out:
# (233, 1)

# %% [markdown]
# # Machine Learning Models for Openness

# %% [markdown]
# #### Spliting Traing and Test data

# %% [markdown]
# Traing 75% and Testing 25%

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(X_new, y_new, test_size = 0.25, random_state = 42)

# %%
from sklearn.metrics import confusion_matrix, multilabel_confusion_matrix, accuracy_score, roc_auc_score, classification_report, plot_roc_curve

# %% [markdown]
# # KNN

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=23)
knn.fit(x_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=23)

# %%
y_pred = knn.predict(x_test)
knn.score(x_test, y_test)
# Out:
# 0.4576271186440678

# %%
print(classification_report(y_test, y_pred))
labels = ['low', 'medium', 'high']
cm = multilabel_confusion_matrix(y_test, y_pred, labels=labels)

for i, label in enumerate(labels):
    tp, fp, fn, tn = cm[i].ravel()
    print(f'Label: {label}')
    print(f'tp={tp}, fn={fn}, fp={fp}, tn={tn}')
# Out:
#               precision    recall  f1-score   support
#
#         high       0.38      0.71      0.49        17
#          low       0.63      0.46      0.53        26
#       medium       0.38      0.19      0.25        16
#
#     accuracy                           0.46        59
#    macro avg       0.46      0.45      0.42        59
# weighted avg       0.49      0.46      0.44        59
#
# Label: low
# tp=26, fn=14, fp=7, tn=12
# Label: medium
# tp=38, fn=13, fp=5, tn=3
# Label: high
# tp=22, fn=5, fp=20, tn=12

# %%
for i, label in enumerate(labels):
    sns.heatmap(cm[i], annot=True, fmt='d', xticklabels=['Predicted 0', 'Predicted 1'], yticklabels=['True 0', 'True 1'])
    plt.title(f'Confusion matrix for label "{label}"')
    plt.show()

# %% [markdown]
# # Decision Tree

# %%
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier
dt = DecisionTreeClassifier(max_depth=7)
dt.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=7)

# %%
# features = x.columns
# features
# targets = openness_df.diagnosis

# %%
y_pred = dt.predict(x_test)

# %%
dt.score(x_test, y_test)
# Out:
# 0.6949152542372882

# %%
print(classification_report(y_test, y_pred))
labels = ['low', 'medium', 'high']
cm = multilabel_confusion_matrix(y_test, y_pred, labels=labels)

for i, label in enumerate(labels):
    tp, fp, fn, tn = cm[i].ravel()
    print(f'Label: {label}')
    print(f'tp={tp}, fn={fn}, fp={fp}, tn={tn}')
# Out:
#               precision    recall  f1-score   support
#
#         high       0.54      0.82      0.65        17
#          low       0.83      0.73      0.78        26
#       medium       0.80      0.50      0.62        16
#
#     accuracy                           0.69        59
#    macro avg       0.72      0.68      0.68        59
# weighted avg       0.74      0.69      0.70        59
#
# Label: low
# tp=29, fn=7, fp=4, tn=19
# Label: medium
# tp=41, fn=8, fp=2, tn=8
# Label: high
# tp=30, fn=3, fp=12, tn=14

# %%
for i, label in enumerate(labels):
    sns.heatmap(cm[i], annot=True, fmt='d', xticklabels=['Predicted 0', 'Predicted 1'], yticklabels=['True 0', 'True 1'])
    plt.title(f'Confusion matrix for label "{label}"')
    plt.show()

# %%
from sklearn.multiclass import OneVsRestClassifier
from sklearn.metrics import roc_curve, auc

# Fit One-vs-Rest Decision Tree Classifier
dt_ovr = OneVsRestClassifier(DecisionTreeClassifier(random_state=42))
dt_ovr.fit(x_train, y_train)

# Predict probabilities of each class
y_pred_proba = dt_ovr.predict_proba(x_test)

# Compute ROC curve and AUC for each class
fpr = dict()
tpr = dict()
roc_auc = dict()
labels = ['low', 'medium', 'high']

for i in range(len(labels)):
    fpr[i], tpr[i], _ = roc_curve(y_test[:, i], y_pred_proba[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# Plot ROC curves for each class
plt.figure()
for i in range(len(labels)):
    plt.plot(fpr[i], tpr[i], label='ROC curve of class %s (AUC = %0.2f)' % (labels[i], roc_auc[i]))

# Plot random guessing line
plt.plot([0, 1], [0, 1], 'k--', label='Random Guessing')

# Set plot parameters
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc="lower right")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\_libs\index.pyx:142, in pandas._libs.index.IndexEngine.get_loc()
#
# TypeError: '(slice(None, None, None), 0)' is an invalid key
#
# During handling of the above exception, another exception occurred:
#
# InvalidIndexError                         Traceback (most recent call last)
# Input In [73], in <cell line: 17>()
#      15 labels = ['low', 'medium', 'high']
#      17 for i in range(len(labels)):
# ---> 18     fpr[i], tpr[i], _ = roc_curve(y_test[:, i], y_pred_proba[:, i])
#      19     roc_auc[i] = auc(fpr[i], tpr[i])
#      21 # Plot ROC curves for each class
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py:3505, in DataFrame.__getitem__(self, key)
#    3503 if self.columns.nlevels > 1:
#    3504     return self._getitem_multilevel(key)
# -> 3505 indexer = self.columns.get_loc(key)
#    3506 if is_integer(indexer):
#    3507     indexer = [indexer]
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py:3628, in Index.get_loc(self, key, method, tolerance)
#    3623         raise KeyError(key) from err
#    3624     except TypeError:
#    3625         # If we have a listlike key, _check_indexing_error will raise
#    3626         #  InvalidIndexError. Otherwise we fall through and re-raise
#    3627         #  the TypeError.
# -> 3628         self._check_indexing_error(key)
#    3629         raise
#    3631 # GH#42269
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py:5637, in Index._check_indexing_error(self, key)
#    5633 def _check_indexing_error(self, key):
#    5634     if not is_scalar(key):
#    5635         # if key is not a scalar, directly raise an error (the code below
#    5636         # would convert to numpy arrays and raise later any way) - GH29926
# -> 5637         raise InvalidIndexError(key)
#
# InvalidIndexError: (slice(None, None, None), 0)

# %% [markdown]
# # Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf_clf = RandomForestClassifier()
rf_clf.fit(x_train, y_train)
rf_clf.score(x_test, y_test)

# %%
print(classification_report(y_test, y_pred))
labels = ['low', 'medium', 'high']
cm = multilabel_confusion_matrix(y_test, y_pred, labels=labels)

for i, label in enumerate(labels):
    tp, fp, fn, tn = cm[i].ravel()
    print(f'Label: {label}')
    print(f'tp={tp}, fn={fn}, fp={fp}, tn={tn}')

# %%
for i, label in enumerate(labels):
    sns.heatmap(cm[i], annot=True, fmt='d', xticklabels=['Predicted 0', 'Predicted 1'], yticklabels=['True 0', 'True 1'])
    plt.title(f'Confusion matrix for label "{label}"')
    plt.show()

# %%
rf_clf = RandomForestClassifier(n_estimators= 100, max_leaf_nodes=16, n_jobs=-1, criterion='entropy', random_state=0)
rf_clf.fit(x_train, y_train)
rf_clf.score(x_test, y_test)

# %% [markdown]
# # Adaboost

# %%
from sklearn.ensemble import AdaBoostClassifier

# %%
ada_clf = AdaBoostClassifier(n_estimators= 100, learning_rate= 0.5)
ada_clf.fit(x_train, y_train)
ada_clf.score(x_test, y_test)

# %%
print(classification_report(y_test, y_pred))
labels = ['low', 'medium', 'high']
cm = multilabel_confusion_matrix(y_test, y_pred, labels=labels)

for i, label in enumerate(labels):
    tp, fp, fn, tn = cm[i].ravel()
    print(f'Label: {label}')
    print(f'tp={tp}, fn={fn}, fp={fp}, tn={tn}')

# %%
for i, label in enumerate(labels):
    sns.heatmap(cm[i], annot=True, fmt='d', xticklabels=['Predicted 0', 'Predicted 1'], yticklabels=['True 0', 'True 1'])
    plt.title(f'Confusion matrix for label "{label}"')
    plt.show()
